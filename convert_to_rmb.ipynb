# %%
import os
import h5py
import numpy as np
import argparse
import cv2
from pathlib import Path

import natsort

# %% [markdown]
# ## Config

# %%
parent_dir = Path("../ALOHATaskCompressedData/"); compressed = True  # ← CHANGE THIS

# %%
for dataset_folder in sorted(parent_dir.iterdir()):
    print(dataset_folder)

    # Using natsort to naturally sort the episode files
    sorted_files = natsort.natsorted(dataset_folder.glob("episode*.hdf5"))

    for hdf5_file in sorted_files:
        print(hdf5_file)
        break
# Out:
# ..\ALOHATaskCompressedData\apply_tape_closed_box
# ..\ALOHATaskCompressedData\apply_tape_closed_box\episode_0.hdf5
# ..\ALOHATaskCompressedData\decompress_visualize_hdf5.ipynb
# ..\ALOHATaskCompressedData\pick_scraper_from_rack
# ..\ALOHATaskCompressedData\pick_scraper_from_rack\episode_0.hdf5
# ..\ALOHATaskCompressedData\usb_mark_003
# ..\ALOHATaskCompressedData\usb_mark_003\episode_0.hdf5

# %%
## CONSTANTS
CAMERA_NAMES = ["cam_high", "cam_left_wrist", "cam_low", "cam_right_wrist"]
DCAMERA_NAMES = ["dcam_high", "dcam_low"]

# %% [markdown]
# ## Helper Function

# %%
def load_compressed_hdf5(dataset_path):
    if not os.path.isfile(dataset_path):
        print(f'Dataset does not exist at \n{dataset_path}\n')
        exit()
    with h5py.File(dataset_path, 'r') as root:
        is_sim = root.attrs['sim']
        qpos = root['/observations/qpos'][()]
        qvel = root['/observations/qvel'][()]
        effort = root['/observations/effort'][()]
        action = root['/action'][()]

        image_dict = dict()
        for cam_name in root[f'/observations/images/'].keys():
            # decode images
            emc_images = root[f'/observations/images/{cam_name}'][()]
            image_dict[cam_name] = list()
            for img in emc_images:
                decompressed_image = cv2.imdecode(img , 1)
                image_dict[cam_name].append(decompressed_image)
    return is_sim, qpos, qvel, effort, action, image_dict

# %%
def load_uncompressed_hdf5(dataset_path):
    if not os.path.isfile(dataset_path):
        print(f'❌ Dataset does not exist at {dataset_path}')
        exit(1)
    with h5py.File(dataset_path, 'r') as root:
        is_sim = root.attrs['sim']
        qpos = root['/observations/qpos'][()]
        qvel = root['/observations/qvel'][()]
        effort = root['/observations/effort'][()]
        action = root['/action'][()]

        image_dict = {}
        for cam_name in root['/observations/images'].keys():
            raw_images = root[f'/observations/images/{cam_name}'][()]
            image_dict[cam_name] = list(raw_images)  # Assume images are already decoded

    return is_sim, qpos, qvel, effort, action, image_dict

# %%
def save_images_to_video(images, out_path, fps=30, is_depth=False):
   
    if images.ndim == 4:  # [T, H, W, C]
        h, w = images.shape[1:3]
    else:  # [T, H, W]
        h, w = images.shape[1:3]
        images = np.expand_dims(images, -1)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(str(out_path), fourcc, fps, (w, h), isColor=True)

    for frame in images:
        if is_depth:
            frame = np.squeeze(frame)
            frame = cv2.normalize(frame, None, 0, 255, cv2.NORM_MINMAX)
            frame = frame.astype(np.uint8)
            frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
        else:
            frame = frame.astype(np.uint8)
        writer.write(frame)

    writer.release()

# %% [markdown]
# ## Dataset Processing

# %%
# Parameters
fps = 30
is_depth = True

# %%
# Process each dataset folder
for dataset_folder in sorted(parent_dir.iterdir()):
    if dataset_folder.is_dir():  
        print(f"📦 Processing: {dataset_folder.name}")

        # Create necessary output directories specific to this dataset
        out_dir = Path(f"./rmb_dataset/{dataset_folder.name}")  

        # Process each .h5 file in the dataset folder
        for i, hdf5_file in enumerate(natsort.natsorted(dataset_folder.glob("episode*.hdf5"))):
            print(f"📦 Processing {hdf5_file.name}")
            episode_name = f"episode_{i:06d}.rmb"
            rmb_dir = out_dir / episode_name
            rmb_dir.mkdir(parents=True, exist_ok=True)

            if compressed:
                # Load and decompress data
                is_sim, qpos, qvel, effort, action, image_dict = load_compressed_hdf5(hdf5_file)
            else:
                is_sim, qpos, qvel, effort, action, image_dict = load_uncompressed_hdf5(hdf5_file)

            # Package image data in flat-key dictionary format
            arrays = {}
            for cam_name, frames in image_dict.items():
                key = f"observations/images/{cam_name}"
                arrays[key] = np.stack(frames, axis=0)  # Convert list to array

            # Handle image data
            for key in arrays:
                if key.startswith("observations/images/"):
                    is_depth = False  # your dataset only has RGB images
                    cam_name = key.split("/")[-1]  # e.g., cam_left_wrist
                    suffix = "rgb_image"
                    video_name = f"{cam_name}_{suffix}.rmb.mp4"
                    print(f"🎞️ Saving video: {video_name} from key: {key}")
                    save_images_to_video(arrays[key], rmb_dir / video_name, fps=fps, is_depth=is_depth)
                        
            print(f"✅ Done: {episode_name}")
# Out:
# 📦 Processing: apply_tape_closed_box
# 📦 Processing episode_0.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000000.rmb
# 📦 Processing episode_1.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000001.rmb
# 📦 Processing episode_2.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000002.rmb
# 📦 Processing episode_3.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000003.rmb
# 📦 Processing episode_4.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000004.rmb
# 📦 Processing episode_5.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000005.rmb
# 📦 Processing episode_6.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000006.rmb
# 📦 Processing episode_7.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000007.rmb
# 📦 Processing episode_8.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000008.rmb
# 📦 Processing episode_9.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000009.rmb
# 📦 Processing episode_10.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000010.rmb
# 📦 Processing episode_11.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000011.rmb
# 📦 Processing episode_12.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000012.rmb
# 📦 Processing episode_13.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000013.rmb
# 📦 Processing episode_14.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000014.rmb
# 📦 Processing episode_15.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000015.rmb
# 📦 Processing episode_16.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000016.rmb
# 📦 Processing episode_17.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000017.rmb
# 📦 Processing episode_18.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000018.rmb
# 📦 Processing episode_19.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000019.rmb
# 📦 Processing episode_20.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000020.rmb
# 📦 Processing episode_21.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000021.rmb
# 📦 Processing episode_22.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000022.rmb
# 📦 Processing episode_23.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000023.rmb
# 📦 Processing episode_24.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000024.rmb
# 📦 Processing episode_25.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000025.rmb
# 📦 Processing episode_26.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000026.rmb
# 📦 Processing episode_27.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_
hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000096.rmb
# 📦 Processing episode_97.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000097.rmb
# 📦 Processing episode_98.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000098.rmb
# 📦 Processing episode_99.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000099.rmb
# 📦 Processing: pick_scraper_from_rack
# 📦 Processing episode_0.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000000.rmb
# 📦 Processing episode_1.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000001.rmb
# 📦 Processing episode_2.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000002.rmb
# 📦 Processing episode_3.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000003.rmb
# 📦 Processing episode_4.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000004.rmb
# 📦 Processing episode_5.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000005.rmb
# 📦 Processing episode_6.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000006.rmb
# 📦 Processing episode_7.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000007.rmb
# 📦 Processing episode_8.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000008.rmb
# 📦 Processing episode_9.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000009.rmb
# 📦 Processing episode_10.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000010.rmb
# 📦 Processing episode_11.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000011.rmb
# 📦 Processing episode_12.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000012.rmb
# 📦 Processing episode_13.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000013.rmb
# 📦 Processing episode_14.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000014.rmb
# 📦 Processing episode_15.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000015.rmb
# 📦 Processing episode_16.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# ...
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000011.rmb
# 📦 Processing episode_12.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000012.rmb
# 📦 Processing episode_13.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000013.rmb
# 📦 Processing episode_14.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000014.rmb
# 📦 Processing episode_15.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000015.rmb
# 📦 Processing episode_16.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000016.rmb
# 📦 Processing episode_17.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000017.rmb
# 📦 Processing episode_18.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000018.rmb
# 📦 Processing episode_19.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000019.rmb
# 📦 Processing episode_20.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000020.rmb
# 📦 Processing episode_21.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000021.rmb
# 📦 Processing episode_22.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000022.rmb
# 📦 Processing episode_23.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000023.rmb
# 📦 Processing episode_24.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000024.rmb
# 📦 Processing episode_25.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000025.rmb
# 📦 Processing episode_26.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000026.rmb
# 📦 Processing episode_27.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000027.rmb
# 📦 Processing episode_28.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000028.rmb
# 📦 Processing episode_29.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000029.rmb
# 📦 Processing episode_30.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000030.rmb
# 📦 Processing episode_31.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000031.rmb
# 📦 Processing episode_32.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000032.rmb
# 📦 Processing episode_33.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000033.rmb
# 📦 Processing episode_34.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000034.rmb
# 📦 Processing episode_35.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000035.rmb
# 📦 Processing episode_36.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000036.rmb
# 📦 Processing episode_37.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000037.rmb
# 📦 Processing episode_38.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000038.rmb
# 📦 Processing episode_39.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000039.rmb
# 📦 Processing episode_40.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000040.rmb
# 📦 Processing episode_41.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000041.rmb
# 📦 Processing episode_42.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000042.rmb
# 📦 Processing episode_43.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000043.rmb
# 📦 Processing episode_44.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000044.rmb
# 📦 Processing episode_45.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000045.rmb
# 📦 Processing episode_46.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000046.rmb
# 📦 Processing episode_47.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000047.rmb
# 📦 Processing episode_48.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000048.rmb
# 📦 Processing episode_49.hdf5
# 🎞️ Saving video: cam_high_rgb_image.rmb.mp4 from key: observations/images/cam_high
# 🎞️ Saving video: cam_left_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_left_wrist
# 🎞️ Saving video: cam_low_rgb_image.rmb.mp4 from key: observations/images/cam_low
# 🎞️ Saving video: cam_right_wrist_rgb_image.rmb.mp4 from key: observations/images/cam_right_wrist
# ✅ Done: episode_000049.rmb

# %% [markdown]
# ---
